# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading-train-data" data-toc-modified-id="Loading-train-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Loading train data</a></span><ul class="toc-item"><li><span><a href="#Merging-train-and-test-data" data-toc-modified-id="Merging-train-and-test-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Merging train and test data</a></span></li><li><span><a href="#Merging-user-data" data-toc-modified-id="Merging-user-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Merging user data</a></span></li><li><span><a href="#Competitions-based-features" data-toc-modified-id="Competitions-based-features-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Competitions based features</a></span></li><li><span><a href="#Competitions-data" data-toc-modified-id="Competitions-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Competitions data</a></span></li><li><span><a href="#Time-based-competitions-features" data-toc-modified-id="Time-based-competitions-features-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Time based competitions features</a></span></li><li><span><a href="#Current-active-competitions-feature" data-toc-modified-id="Current-active-competitions-feature-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Current active competitions feature</a></span></li><li><span><a href="#User-Interests-Feature" data-toc-modified-id="User-Interests-Feature-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>User Interests Feature</a></span></li><li><span><a href="#Submissions-based-features" data-toc-modified-id="Submissions-based-features-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Submissions based features</a></span></li><li><span><a href="#Discussion-based-features" data-toc-modified-id="Discussion-based-features-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Discussion based features</a></span></li><li><span><a href="#Comments-based-features" data-toc-modified-id="Comments-based-features-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Comments based features</a></span></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Modeling</a></span></li><li><span><a href="#Submission" data-toc-modified-id="Submission-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Submission</a></span></li></ul></div>

# %%
#!pip uninstall -r requirements.txt
# Out:
# Found existing installation: anyio 3.7.1
# Uninstalling anyio-3.7.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/anyio-3.7.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/anyio/*
# Proceed (Y/n)? y
#   Successfully uninstalled anyio-3.7.1
# Found existing installation: argon2-cffi 23.1.0
# Uninstalling argon2-cffi-23.1.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/argon2/*
#     /usr/local/lib/python3.10/dist-packages/argon2_cffi-23.1.0.dist-info/*
# Proceed (Y/n)? y
#   Successfully uninstalled argon2-cffi-23.1.0
# Found existing installation: argon2-cffi-bindings 21.2.0
# Uninstalling argon2-cffi-bindings-21.2.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/_argon2_cffi_bindings/*
#     /usr/local/lib/python3.10/dist-packages/argon2_cffi_bindings-21.2.0.dist-info/*
# Proceed (Y/n)? y
#   Successfully uninstalled argon2-cffi-bindings-21.2.0
# Found existing installation: attrs 24.2.0
# Uninstalling attrs-24.2.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/attr/*
#     /usr/local/lib/python3.10/dist-packages/attrs-24.2.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/attrs/*
# Proceed (Y/n)? y
#   Successfully uninstalled attrs-24.2.0
# Found existing installation: babel 2.16.0
# Uninstalling babel-2.16.0:
#   Would remove:
#     /usr/local/bin/pybabel
#     /usr/local/lib/python3.10/dist-packages/babel-2.16.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/babel/*
# Proceed (Y/n)? y
#   Successfully uninstalled babel-2.16.0
# Found existing installation: backcall 0.2.0
# Uninstalling backcall-0.2.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/backcall-0.2.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/backcall/*
# Proceed (Y/n)? y
#   Successfully uninstalled backcall-0.2.0
# Found existing installation: bleach 6.1.0
# Uninstalling bleach-6.1.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/bleach-6.1.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/bleach/*
# Proceed (Y/n)? y
#   Successfully uninstalled bleach-6.1.0
# Found existing installation: catboost 1.2.7
# Uninstalling catboost-1.2.7:
#   Would remove:
#     /usr/local/etc/jupyter/nbconfig/notebook.d/catboost-widget.json
#     /usr/local/lib/python3.10/dist-packages/catboost-1.2.7.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/catboost/*
#     /usr/local/share/jupyter/labextensions/catboost-widget/package.json
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/138.1b18795f1631648f3df1.js
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/479.d43617224b25ecf15b1d.js
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/479.d43617224b25ecf15b1d.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/486.bafd26b008c3405f7750.js
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/486.bafd26b008c3405f7750.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/755.297bcad6e07632169fc2.js
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/755.297bcad6e07632169fc2.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/908.81f6af6c7d6425b98663.js
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/remoteEntry.71e5662234b926b21a28.js
#     /usr/local/share/jupyter/labextensions/catboost-widget/static/style.js
#     /usr/local/share/jupyter/nbextensions/catboost-widget/extension.js
#     /usr/local/share/jupyter/nbextensions/catboost-widget/index.js
# Proceed (Y/n)? y
#   Successfully uninstalled catboost-1.2.7
# Found existing installation: category-encoders 2.6.4
# Uninstalling category-encoders-2.6.4:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/category_encoders-2.6.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/category_encoders/*
# Proceed (Y/n)? y
#   Successfully uninstalled category-encoders-2.6.4
# Found existing installation: certifi 2024.8.30
# Uninstalling certifi-2024.8.30:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/certifi-2024.8.30.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/certifi/*
# Proceed (Y/n)? y
#   Successfully uninstalled certifi-2024.8.30
# Found existing installation: cffi 1.17.1
# Uninstalling cffi-1.17.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/_cffi_backend.cpython-310-x86_64-linux-gnu.so
#     /usr/local/lib/python3.10/dist-packages/cffi-1.17.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/cffi/*
# Proceed (Y/n)? y
# y
# y
# y
#   Successfully uninstalled cffi-1.17.1
# Found existing installation: charset-normalizer 3.4.0
# Uninstalling charset-normalizer-3.4.0:
#   Would remove:
#     /usr/local/bin/normalizer
#     /usr/local/lib/python3.10/dist-packages/charset_normalizer-3.4.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/charset_normalizer/*
# Proceed (Y/n)?   Successfully uninstalled charset-normalizer-3.4.0
# Found existing installation: cycler 0.12.1
# Uninstalling cycler-0.12.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/cycler-0.12.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/cycler/*
# Proceed (Y/n)?   Successfully uninstalled cycler-0.12.1
# Found existing installation: debugpy 1.6.6
# Uninstalling debugpy-1.6.6:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/debugpy-1.6.6.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/debugpy/*
# Proceed (Y/n)?   Successfully uninstalled debugpy-1.6.6
# Found existing installation: decorator 4.4.2
# Uninstalling decorator-4.4.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/decorator-4.4.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/decorator.py
# Proceed (Y/n)? y
#   Successfully uninstalled decorator-4.4.2
# Found existing installation: defusedxml 0.7.1
# Uninstalling defusedxml-0.7.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/defusedxml-0.7.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/defusedxml/*
# Proceed (Y/n)? y
#   Successfully uninstalled defusedxml-0.7.1
# Found existing installation: entrypoints 0.4
# Uninstalling entrypoints-0.4:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/entrypoints-0.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/entrypoints.py
# Proceed (Y/n)? y
#   Successfully uninstalled entrypoints-0.4
# Found existing installation: fonttools 4.54.1
# Uninstalling fonttools-4.54.1:
#   Would remove:
#     /usr/local/bin/fonttools
#     /usr/local/bin/pyftmerge
#     /usr/local/bin/pyftsubset
#     /usr/local/bin/ttx
#     /usr/local/lib/python3.10/dist-packages/fontTools/*
#     /usr/local/lib/python3.10/dist-packages/fonttools-4.54.1.dist-info/*
#     /usr/local/share/man/man1/ttx.1
# Proceed (Y/n)? y
#   Successfully uninstalled fonttools-4.54.1
# Found existing installation: graphviz 0.20.3
# Uninstalling graphviz-0.20.3:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/graphviz-0.20.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/graphviz/*
# Proceed (Y/n)? y
#   Successfully uninstalled graphviz-0.20.3
# Found existing installation: idna 3.10
# Uninstalling idna-3.10:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/idna-3.10.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/idna/*
# Proceed (Y/n)? y
#   Successfully uninstalled idna-3.10
# Found existing installation: importlib_metadata 8.5.0
# Uninstalling importlib_metadata-8.5.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/importlib_metadata-8.5.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/importlib_metadata/*
# Proceed (Y/n)?
#   Successfully uninstalled importlib_metadata-8.5.0
# Found existing installation: importlib_resources 6.4.5
# Uninstalling importlib_resources-6.4.5:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/importlib_resources-6.4.5.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/importlib_resources/*
# Proceed (Y/n)? y
#   Successfully uninstalled importlib_resources-6.4.5
# Found existing installation: ipykernel 5.5.6
# Uninstalling ipykernel-5.5.6:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/ipykernel-5.5.6.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/ipykernel/*
#     /usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py
#     /usr/local/share/jupyter/kernels/python3/kernel.json
#     /usr/local/share/jupyter/kernels/python3/logo-32x32.png
#     /usr/local/share/jupyter/kernels/python3/logo-64x64.png
# Proceed (Y/n)? y
# y
#   Successfully uninstalled ipykernel-5.5.6
# Found existing installation: ipython 7.34.0
# Uninstalling ipython-7.34.0:
#   Would remove:
#     /usr/local/bin/iptest
#     /usr/local/bin/iptest3
#     /usr/local/bin/ipython
#     /usr/local/bin/ipython3
#     /usr/local/lib/python3.10/dist-packages/IPython/*
#     /usr/local/lib/python3.10/dist-packages/ipython-7.34.0.dist-info/*
#     /usr/local/share/man/man1/ipython.1.gz
# Proceed (Y/n)?   Successfully uninstalled ipython-7.34.0
# Found existing installation: ipython-genutils 0.2.0
# Uninstalling ipython-genutils-0.2.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/ipython_genutils-0.2.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/ipython_genutils/*
# Proceed (Y/n)? y
#   Successfully uninstalled ipython-genutils-0.2.0
# Found existing installation: ipywidgets 7.7.1
# Uninstalling ipywidgets-7.7.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/ipywidgets-7.7.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/ipywidgets/*
# Proceed (Y/n)? y
#   Successfully uninstalled ipywidgets-7.7.1
# WARNING: Skipping jedi as it is not installed.
# Found existing installation: Jinja2 3.1.4
# Uninstalling Jinja2-3.1.4:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/jinja2-3.1.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jinja2/*
# Proceed (Y/n)? y
#   Successfully uninstalled Jinja2-3.1.4
# Found existing installation: joblib 1.4.2
# Uninstalling joblib-1.4.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/joblib-1.4.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/joblib/*
# Proceed (Y/n)?
#   Successfully uninstalled joblib-1.4.2
# WARNING: Skipping json5 as it is not installed.
# Found existing installation: jsonschema 4.23.0
# Uninstalling jsonschema-4.23.0:
#   Would remove:
#     /usr/local/bin/jsonschema
#     /usr/local/lib/python3.10/dist-packages/jsonschema-4.23.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jsonschema/*
# Proceed (Y/n)? y
#   Successfully uninstalled jsonschema-4.23.0
# Found existing installation: jupyter-client 6.1.12
# Uninstalling jupyter-client-6.1.12:
#   Would remove:
#     /usr/local/bin/jupyter-kernel
#     /usr/local/bin/jupyter-kernelspec
#     /usr/local/bin/jupyter-run
#     /usr/local/lib/python3.10/dist-packages/jupyter_client-6.1.12.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jupyter_client/*
# Proceed (Y/n)? y
#   Successfully uninstalled jupyter-client-6.1.12
# Found existing installation: jupyter_core 5.7.2
# Uninstalling jupyter_core-5.7.2:
#   Would remove:
#     /usr/local/bin/jupyter
#     /usr/local/bin/jupyter-migrate
#     /usr/local/bin/jupyter-troubleshoot
#     /usr/local/lib/python3.10/dist-packages/jupyter.py
#     /usr/local/lib/python3.10/dist-packages/jupyter_core-5.7.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jupyter_core/*
# Proceed (Y/n)?
# y
# y
#   Successfully uninstalled jupyter_core-5.7.2
# Found existing installation: jupyter-server 1.24.0
# Uninstalling jupyter-server-1.24.0:
#   Would remove:
#     /usr/local/bin/jupyter-server
#     /usr/local/lib/python3.10/dist-packages/jupyter_server-1.24.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jupyter_server/*
# Proceed (Y/n)?   Successfully uninstalled jupyter-server-1.24.0
# WARNING: Skipping jupyterlab as it is not installed.
# Found existing installation: jupyterlab_pygments 0.3.0
# Uninstalling jupyterlab_pygments-0.3.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/jupyterlab_pygments-0.3.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jupyterlab_pygments/*
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/install.json
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/package.json
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/static/568.1e2faa2ba0bbe59c4780.js
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/static/747.67662283a5707eeb4d4c.js
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/static/remoteEntry.5cbb9d2323598fbda535.js
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/static/style.js
#     /usr/local/share/jupyter/labextensions/jupyterlab_pygments/static/third-party-licenses.json
# Proceed (Y/n)?   Successfully uninstalled jupyterlab_pygments-0.3.0
# WARNING: Skipping jupyterlab-server as it is not installed.
# Found existing installation: jupyterlab_widgets 3.0.13
# Uninstalling jupyterlab_widgets-3.0.13:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/jupyterlab_widgets-3.0.13.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jupyterlab_widgets/*
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/install.json
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/package.json
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas/@jupyter-widgets/jupyterlab-manager/package.json.orig
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas/@jupyter-widgets/jupyterlab-manager/plugin.json
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/327.8166aeb81cf1531ca240.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/39.f95d17ff2501dcd0834e.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/420.063e2ee9f71033206b1f.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/439.33696bc45fbd403becbb.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/439.33696bc45fbd403becbb.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/446.bf169bd3821a9ba1aa62.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/586.5a62b313f9ec1d9df348.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/647.f4f9578285e357c95be3.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/651.fe40a967a60b543cf15c.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/651.fe40a967a60b543cf15c.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/701.043aefe0b66133629348.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/722.3fefeac9cae358348cbc.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/727.2abc0b27bd0932fb5f81.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/898.4051a8b212a0f4c89d60.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/remoteEntry.e4ff09401a2f575928c0.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/style.js
#     /usr/local/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/third-party-licenses.json
# Proceed (Y/n)? y
#   Successfully uninstalled jupyterlab_widgets-3.0.13
# Found existing installation: kiwisolver 1.4.7
# Uninstalling kiwisolver-1.4.7:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/kiwisolver-1.4.7.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/kiwisolver/*
# Proceed (Y/n)? y
#   Successfully uninstalled kiwisolver-1.4.7
# Found existing installation: lightgbm 4.5.0
# Uninstalling lightgbm-4.5.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/lightgbm-4.5.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/lightgbm/*
# Proceed (Y/n)?
#   Successfully uninstalled lightgbm-4.5.0
# Found existing installation: MarkupSafe 3.0.1
# Uninstalling MarkupSafe-3.0.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/MarkupSafe-3.0.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/markupsafe/*
# Proceed (Y/n)?
#   Successfully uninstalled MarkupSafe-3.0.1
# Found existing installation: matplotlib 3.7.1
# Uninstalling matplotlib-3.7.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/matplotlib-3.7.1-py3.10-nspkg.pth
#     /usr/local/lib/python3.10/dist-packages/matplotlib-3.7.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/matplotlib/*
#     /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axes_grid1/*
#     /usr/local/lib/python3.10/dist-packages/mpl_toolkits/axisartist/*
#     /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/*
#     /usr/local/lib/python3.10/dist-packages/pylab.py
# Proceed (Y/n)?
# y
#
# y
# y
#   Successfully uninstalled matplotlib-3.7.1
# Found existing installation: matplotlib-inline 0.1.7
# Uninstalling matplotlib-inline-0.1.7:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/matplotlib_inline-0.1.7.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/matplotlib_inline/*
# Proceed (Y/n)?   Successfully uninstalled matplotlib-inline-0.1.7
# Found existing installation: mistune 0.8.4
# Uninstalling mistune-0.8.4:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/mistune-0.8.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/mistune.py
# Proceed (Y/n)? y
#
# y
# y
# y
#
#
#   Successfully uninstalled mistune-0.8.4
# y
# y
# Found existing installation: nbclassic 1.1.0
# Uninstalling nbclassic-1.1.0:
#   Would remove:
#     /usr/local/bin/jupyter-nbclassic
#     /usr/local/bin/jupyter-nbclassic-bundlerextension
#     /usr/local/bin/jupyter-nbclassic-extension
#     /usr/local/bin/jupyter-nbclassic-serverextension
#     /usr/local/etc/jupyter/jupyter_server_config.d/nbclassic.json
#     /usr/local/lib/python3.10/dist-packages/nbclassic-1.1.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/nbclassic/*
#     /usr/local/share/applications/jupyter-nbclassic.desktop
#     /usr/local/share/icons/hicolor/scalable/apps/nbclassic.svg
# Proceed (Y/n)?
# y
# y
#
# y
# y
# y
#   Successfully uninstalled nbclassic-1.1.0
# y
# y
# Found existing installation: nbclient 0.10.0
# Uninstalling nbclient-0.10.0:
#   Would remove:
#     /usr/local/bin/jupyter-execute
#     /usr/local/lib/python3.10/dist-packages/nbclient-0.10.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/nbclient/*
# Proceed (Y/n)?   Successfully uninstalled nbclient-0.10.0
# Found existing installation: nbconvert 6.5.4
# Uninstalling nbconvert-6.5.4:
#   Would remove:
#     /usr/local/bin/jupyter-dejavu
#     /usr/local/bin/jupyter-nbconvert
#     /usr/local/lib/python3.10/dist-packages/nbconvert-6.5.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/nbconvert/*
#     /usr/local/share/jupyter/nbconvert/templates/asciidoc/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/asciidoc/index.asciidoc.j2
#     /usr/local/share/jupyter/nbconvert/templates/base/celltags.j2
#     /usr/local/share/jupyter/nbconvert/templates/base/display_priority.j2
#     /usr/local/share/jupyter/nbconvert/templates/base/jupyter_widgets.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/base/mathjax.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/base/null.j2
#     /usr/local/share/jupyter/nbconvert/templates/basic/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/basic/index.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/classic/base.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/classic/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/classic/index.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/classic/static/style.css
#     /usr/local/share/jupyter/nbconvert/templates/compatibility/display_priority.tpl
#     /usr/local/share/jupyter/nbconvert/templates/compatibility/full.tpl
#     /usr/local/share/jupyter/nbconvert/templates/lab/base.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/lab/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/lab/index.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/lab/static/index.css
#     /usr/local/share/jupyter/nbconvert/templates/lab/static/theme-dark.css
#     /usr/local/share/jupyter/nbconvert/templates/lab/static/theme-light.css
#     /usr/local/share/jupyter/nbconvert/templates/latex/base.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/latex/display_priority.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/document_contents.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/index.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/null.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/report.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/style_bw_ipython.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/style_bw_python.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/style_ipython.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/style_jupyter.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/latex/style_python.tex.j2
#     /usr/local/share/jupyter/nbconvert/templates/markdown/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/markdown/index.md.j2
#     /usr/local/share/jupyter/nbconvert/templates/python/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/python/index.py.j2
#     /usr/local/share/jupyter/nbconvert/templates/reveal/base.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/reveal/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/reveal/index.html.j2
#     /usr/local/share/jupyter/nbconvert/templates/reveal/static/custom_reveal.css
#     /usr/local/share/jupyter/nbconvert/templates/rst/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/rst/index.rst.j2
#     /usr/local/share/jupyter/nbconvert/templates/script/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/script/script.j2
#     /usr/local/share/jupyter/nbconvert/templates/webpdf/conf.json
#     /usr/local/share/jupyter/nbconvert/templates/webpdf/index.pdf.j2
# Proceed (Y/n)? y
#   Successfully uninstalled nbconvert-6.5.4
# Found existing installation: nbformat 5.10.4
# Uninstalling nbformat-5.10.4:
#   Would remove:
#     /usr/local/bin/jupyter-trust
#     /usr/local/lib/python3.10/dist-packages/nbformat-5.10.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/nbformat/*
# Proceed (Y/n)? y
#   Successfully uninstalled nbformat-5.10.4
# Found existing installation: nest-asyncio 1.6.0
# Uninstalling nest-asyncio-1.6.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/nest_asyncio-1.6.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/nest_asyncio.py
# Proceed (Y/n)?
# y
# y
# y
# y
# y
#
#
# y
#
#   Successfully uninstalled nest-asyncio-1.6.0
# Found existing installation: notebook 6.5.5
# Uninstalling notebook-6.5.5:
#   Would remove:
#     /usr/local/bin/jupyter-bundlerextension
#     /usr/local/bin/jupyter-nbextension
#     /usr/local/bin/jupyter-notebook
#     /usr/local/bin/jupyter-serverextension
#     /usr/local/lib/python3.10/dist-packages/notebook-6.5.5.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/notebook/*
#     /usr/local/share/applications/jupyter-notebook.desktop
#     /usr/local/share/icons/hicolor/scalable/apps/notebook.svg
# Proceed (Y/n)? y
#   Successfully uninstalled notebook-6.5.5
# Found existing installation: numpy 1.26.4
# y
# Uninstalling numpy-1.26.4:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/lib/python3.10/dist-packages/numpy-1.26.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libopenblas64_p-r0-0cf96a72.3.23.dev.so
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy/*
# Proceed (Y/n)? yy
# y
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: packaging 24.1
# Uninstalling packaging-24.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/packaging-24.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/packaging/*
# Proceed (Y/n)?   Successfully uninstalled packaging-24.1
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pandas-2.2.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pandas/*
# Proceed (Y/n)? y
# y
#   Successfully uninstalled pandas-2.2.2
# Found existing installation: pandocfilters 1.5.1
# Uninstalling pandocfilters-1.5.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pandocfilters-1.5.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pandocfilters.py
# Proceed (Y/n)? y
#
#   Successfully uninstalled pandocfilters-1.5.1
# Found existing installation: parso 0.8.4
# Uninstalling parso-0.8.4:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/parso-0.8.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/parso/*
# Proceed (Y/n)?   Successfully uninstalled parso-0.8.4
# Found existing installation: patsy 0.5.6
# Uninstalling patsy-0.5.6:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/patsy-0.5.6.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/patsy/*
# Proceed (Y/n)?   Successfully uninstalled patsy-0.5.6
# Found existing installation: pexpect 4.9.0
# Uninstalling pexpect-4.9.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pexpect-4.9.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pexpect/*
# Proceed (Y/n)?   Successfully uninstalled pexpect-4.9.0
# Found existing installation: pickleshare 0.7.5
# Uninstalling pickleshare-0.7.5:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pickleshare-0.7.5.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pickleshare.py
# Proceed (Y/n)? y
# y
#   Successfully uninstalled pickleshare-0.7.5
# Found existing installation: pillow 10.4.0
# Uninstalling pillow-10.4.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/PIL/*
#     /usr/local/lib/python3.10/dist-packages/pillow-10.4.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libXau-154567c4.so.6.0.0
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libbrotlicommon-3ecfe81c.so.1
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libbrotlidec-ba690955.so.1
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libfreetype-be14bf51.so.6.20.1
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libharfbuzz-89381d8f.so.0.60850.0
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libjpeg-77ae51ab.so.62.4.0
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/liblcms2-e69eef39.so.2.0.16
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/liblzma-13fa198c.so.5.4.5
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libopenjp2-05423b53.so
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libpng16-58efbb84.so.16.43.0
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libsharpyuv-898c0cb5.so.0.1.0
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libtiff-0a86184d.so.6.0.2
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libwebp-2fd3cdca.so.7.1.9
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libwebpdemux-f2642bcc.so.2.0.15
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libwebpmux-d524b4d5.so.3.1.0
#     /usr/local/lib/python3.10/dist-packages/pillow.libs/libxcb-b8a56d01.so.1.1.0
# Proceed (Y/n)?   Successfully uninstalled pillow-10.4.0
# Found existing installation: plotly 5.24.1
#
#
# y
# Uninstalling plotly-5.24.1:
#
#   Would remove:
#     /usr/local/etc/jupyter/nbconfig/notebook.d/jupyterlab-plotly.json
#     /usr/local/lib/python3.10/dist-packages/_plotly_future_/*
#     /usr/local/lib/python3.10/dist-packages/_plotly_utils/*
#     /usr/local/lib/python3.10/dist-packages/jupyterlab_plotly/*
#     /usr/local/lib/python3.10/dist-packages/plotly-5.24.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/plotly/*
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/package.json
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/133.d03e1dd786ee2967a117.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/423.d0d3e2912c33c7566484.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/478.fdc0539db81116781109.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/478.fdc0539db81116781109.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/486.6450efe6168c2f8caddb.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/486.6450efe6168c2f8caddb.js.LICENSE.txt
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/657.d00745f2277e50b85be7.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/855.323c80e7298812d692e7.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/remoteEntry.c6c768d682b3638efd6b.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/style.js
#     /usr/local/share/jupyter/labextensions/jupyterlab-plotly/static/third-party-licenses.json
#     /usr/local/share/jupyter/nbextensions/jupyterlab-plotly/extension.js
#     /usr/local/share/jupyter/nbextensions/jupyterlab-plotly/index.js
#     /usr/local/share/jupyter/nbextensions/jupyterlab-plotly/index.js.LICENSE.txt
# Proceed (Y/n)? y
# y
# y
# y
# y
# y
#
# y
# y
# y
# y
#
# y
# y
#
#   Successfully uninstalled plotly-5.24.1
# Found existing installation: prometheus_client 0.21.0
# Uninstalling prometheus_client-0.21.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/prometheus_client-0.21.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/prometheus_client/*
# Proceed (Y/n)?   Successfully uninstalled prometheus_client-0.21.0
# Found existing installation: prompt_toolkit 3.0.48
# Uninstalling prompt_toolkit-3.0.48:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/prompt_toolkit-3.0.48.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/prompt_toolkit/*
# Proceed (Y/n)?   Successfully uninstalled prompt_toolkit-3.0.48
# Found existing installation: ptyprocess 0.7.0
# Uninstalling ptyprocess-0.7.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/ptyprocess-0.7.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/ptyprocess/*
# Proceed (Y/n)?   Successfully uninstalled ptyprocess-0.7.0
# Found existing installation: pycparser 2.22
# Uninstalling pycparser-2.22:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pycparser-2.22.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pycparser/*
# Proceed (Y/n)?   Successfully uninstalled pycparser-2.22
# Found existing installation: Pygments 2.18.0
# Uninstalling Pygments-2.18.0:
#   Would remove:
#     /usr/local/bin/pygmentize
#     /usr/local/lib/python3.10/dist-packages/pygments-2.18.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pygments/*
# Proceed (Y/n)?   Successfully uninstalled Pygments-2.18.0
# Found existing installation: pyparsing 3.2.0
# Uninstalling pyparsing-3.2.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pyparsing-3.2.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pyparsing/*
# Proceed (Y/n)?   Successfully uninstalled pyparsing-3.2.0
# WARNING: Skipping pyrsistent as it is not installed.
# Found existing installation: python-dateutil 2.8.2
# Uninstalling python-dateutil-2.8.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/dateutil/*
#     /usr/local/lib/python3.10/dist-packages/python_dateutil-2.8.2.dist-info/*
# Proceed (Y/n)?   Successfully uninstalled python-dateutil-2.8.2
# Found existing installation: pytz 2024.2
# Uninstalling pytz-2024.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pytz-2024.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pytz/*
# Proceed (Y/n)?   Successfully uninstalled pytz-2024.2
# Found existing installation: pyzmq 24.0.1
# Uninstalling pyzmq-24.0.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pyzmq-24.0.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pyzmq.libs/libsodium-a0cd10d3.so.23.3.0
#     /usr/local/lib/python3.10/dist-packages/pyzmq.libs/libzmq-fc4fcd2d.so.5.2.4
#     /usr/local/lib/python3.10/dist-packages/zmq/*
# Proceed (Y/n)?   Successfully uninstalled pyzmq-24.0.1
# Found existing installation: requests 2.32.3
# Uninstalling requests-2.32.3:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/requests-2.32.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/requests/*
# Proceed (Y/n)?   Successfully uninstalled requests-2.32.3
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/scikit_learn-1.5.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/scikit_learn.libs/libgomp-a34b3233.so.1.0.0
#     /usr/local/lib/python3.10/dist-packages/sklearn/*
# Proceed (Y/n)?   Successfully uninstalled scikit-learn-1.5.2
# Found existing installation: scipy 1.13.1
# Uninstalling scipy-1.13.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/scipy-1.13.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/scipy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.10/dist-packages/scipy.libs/libopenblasp-r0-01191904.3.27.so
#     /usr/local/lib/python3.10/dist-packages/scipy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/scipy/*
# Proceed (Y/n)?   Successfully uninstalled scipy-1.13.1
# Found existing installation: Send2Trash 1.8.3
# Uninstalling Send2Trash-1.8.3:
#   Would remove:
#     /usr/local/bin/send2trash
#     /usr/local/lib/python3.10/dist-packages/Send2Trash-1.8.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/send2trash/*
# Proceed (Y/n)?   Successfully uninstalled Send2Trash-1.8.3
# WARNING: Skipping setuptools-scm as it is not installed.
# Found existing installation: six 1.16.0
# Uninstalling six-1.16.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/six-1.16.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/six.py
# Proceed (Y/n)?   Successfully uninstalled six-1.16.0
# Found existing installation: sniffio 1.3.1
# Uninstalling sniffio-1.3.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/sniffio-1.3.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/sniffio/*
# Proceed (Y/n)?   Successfully uninstalled sniffio-1.3.1
# Found existing installation: statsmodels 0.14.4
# Uninstalling statsmodels-0.14.4:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/statsmodels-0.14.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/statsmodels/*
# Proceed (Y/n)?   Successfully uninstalled statsmodels-0.14.4
# Found existing installation: tenacity 9.0.0
# Uninstalling tenacity-9.0.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/tenacity-9.0.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tenacity/*
# Proceed (Y/n)?   Successfully uninstalled tenacity-9.0.0
# Found existing installation: terminado 0.18.1
# Uninstalling terminado-0.18.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/terminado-0.18.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/terminado/*
# Proceed (Y/n)?   Successfully uninstalled terminado-0.18.1
# WARNING: Skipping testpath as it is not installed.
# Found existing installation: threadpoolctl 3.5.0
# Uninstalling threadpoolctl-3.5.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/threadpoolctl-3.5.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/threadpoolctl.py
# Proceed (Y/n)? Your response ('yy') was not one of the expected responses: y, n,
# Proceed (Y/n)?   Successfully uninstalled threadpoolctl-3.5.0
# Found existing installation: tomli 2.0.2
# Uninstalling tomli-2.0.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/tomli-2.0.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tomli/*
# Proceed (Y/n)?   Successfully uninstalled tomli-2.0.2
# Found existing installation: tornado 6.3.3
# Uninstalling tornado-6.3.3:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/tornado-6.3.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tornado/*
# Proceed (Y/n)?   Successfully uninstalled tornado-6.3.3
# Found existing installation: tqdm 4.66.5
# Uninstalling tqdm-4.66.5:
#   Would remove:
#     /usr/local/bin/tqdm
#     /usr/local/lib/python3.10/dist-packages/tqdm-4.66.5.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tqdm/*
# Proceed (Y/n)?   Successfully uninstalled tqdm-4.66.5
# Found existing installation: traitlets 5.7.1
# Uninstalling traitlets-5.7.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/traitlets-5.7.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/traitlets/*
# Proceed (Y/n)?   Successfully uninstalled traitlets-5.7.1
# Found existing installation: typing_extensions 4.12.2
# Uninstalling typing_extensions-4.12.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/typing_extensions-4.12.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/typing_extensions.py
# Proceed (Y/n)?   Successfully uninstalled typing_extensions-4.12.2
# Found existing installation: urllib3 2.2.3
# Uninstalling urllib3-2.2.3:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/urllib3-2.2.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/urllib3/*
# Proceed (Y/n)?   Successfully uninstalled urllib3-2.2.3
# Found existing installation: wcwidth 0.2.13
# Uninstalling wcwidth-0.2.13:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/wcwidth-0.2.13.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/wcwidth/*
# Proceed (Y/n)?   Successfully uninstalled wcwidth-0.2.13
# Found existing installation: webencodings 0.5.1
# Uninstalling webencodings-0.5.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/webencodings-0.5.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/webencodings/*
# Proceed (Y/n)?   Successfully uninstalled webencodings-0.5.1
# Found existing installation: websocket-client 1.8.0
# Uninstalling websocket-client-1.8.0:
#   Would remove:
#     /usr/local/bin/wsdump
#     /usr/local/lib/python3.10/dist-packages/websocket/*
#     /usr/local/lib/python3.10/dist-packages/websocket_client-1.8.0.dist-info/*
# Proceed (Y/n)?   Successfully uninstalled websocket-client-1.8.0
# Found existing installation: widgetsnbextension 3.6.9
# Uninstalling widgetsnbextension-3.6.9:
#   Would remove:
#     /usr/local/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json
#     /usr/local/lib/python3.10/dist-packages/widgetsnbextension-3.6.9.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/widgetsnbextension/*
#     /usr/local/share/jupyter/nbextensions/jupyter-js-widgets/extension.js
#     /usr/local/share/jupyter/nbextensions/jupyter-js-widgets/extension.js.map
# Proceed (Y/n)?   Successfully uninstalled widgetsnbextension-3.6.9
# Found existing installation: zipp 3.20.2
# Uninstalling zipp-3.20.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/zipp-3.20.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/zipp/*
# Proceed (Y/n)?   Successfully uninstalled zipp-3.20.2

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.4

# %%
#%reload_ext autoreload
# %autoreload 2

import os
import gc
import sys
import random
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option("max_colwidth", None)
#pd.set_option("max_columns", 500)
#pd.set_option("max_rows", 500)

plt.style.use('fivethirtyeight')
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14

from sklearn.model_selection import StratifiedKFold, GroupKFold
from catboost import CatBoostClassifier
from category_encoders import CountEncoder
import lightgbm as lgb

# %matplotlib inline

# %%
class Config:
    LAG = 3
    VER = f'final_sub_v1'
    OUTPUT_DIR = '/content'
    DATA_DIR = '/content'
    DEBUG = True
    N_SPLITS = 5

# %%
LOCAL_TEST_RUN = False

def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)

seed_everything()

# %% [markdown]
# # Loading train data

# %%
def determine_target(df):
    new_target = []
    for i, row in df.iterrows():
        if row['CompPart'] == 1:
            new_target.append('CompPart')
            continue
        elif row['Sub'] == 1 or row['Comment'] == 1 or row['Disc'] == 1:
            new_target.append('Sub')
            continue
        else:
            new_target.append('NoActivity')

    return new_target

# %%
train = pd.read_csv(os.path.join(Config.DATA_DIR,"Train.csv"), index_col=None)
print(train.shape)
train['Target'] = determine_target(train)
train.head()
# Out:
# (259832, 8)
#        User_ID  month  year  CompPart  Comment  Sub  Disc      Target
# 0  ID_XI7BAR4Y      8     3         0        0    0     0  NoActivity
# 1  ID_XI7BAR4Y      8     2         0        0    0     0  NoActivity
# 2  ID_XI7BAR4Y      9     2         0        0    0     0  NoActivity
# 3  ID_XI7BAR4Y      9     3         0        0    0     0  NoActivity
# 4  ID_XI7BAR4Y     10     3         0        0    0     0  NoActivity

# %%
if LOCAL_TEST_RUN:
    test_index = (train['year']==3)&(train['month'].isin([10,11,12]))
    test = train[test_index].reset_index(drop=True)
    train = train[~test_index].reset_index(drop=True)
else:
    test = pd.read_csv(os.path.join(Config.DATA_DIR,"Test.csv"), index_col=None)

print(test.shape)
test.head()
# Out:
# (65223, 3)
#        User_ID  month  year
# 0  ID_H1ELY25E      1     4
# 1  ID_H1ELY25E      2     4
# 2  ID_H1ELY25E      3     4
# 3  ID_463Q2BCO      1     4
# 4  ID_463Q2BCO      2     4

# %% [markdown]
# ## Merging train and test data

# %%
def determine_timestamp(df):
    df['year_month'] = (
        df['year'].astype(str) +
        df['month'].apply(lambda x: str(x).zfill(2))
    ).astype(int)
    df = df.sort_values(by='year_month').reset_index(drop=True)
    df['timestamp'] = np.arange(1, len(df) + 1)

    return df

print(train.shape, test.shape)
train['is_train'] = 1
test['is_train'] = 0


overall = pd.concat([train, test], ignore_index=True)
#overall = train.append(test, ignore_index=True)
timestamp = overall[['year', 'month']].drop_duplicates()
timestamp = determine_timestamp(timestamp)
overall = overall.merge(timestamp, how='left')
all_timestamps = overall[['User_ID', 'timestamp', 'year', 'month']].drop_duplicates().reset_index(drop=True)

overall = overall.sort_values(by='timestamp').reset_index(drop=True)
overall['Record'] = 1
overall
new_column = overall.groupby('User_ID')['Record'].apply(lambda x: x.cumsum())
overall['Total_Num_User_Months'] = new_column.reset_index(level=0, drop=True)
# Out:
# (259832, 9) (65223, 4)

# %% [markdown]
# ## Merging user data

# %%
users = pd.read_csv(os.path.join(Config.DATA_DIR,"Users.csv"), index_col=None)
users.columns = ['User_ID', 'FeatureX', 'Country', 'FeatureY', 'Points', 'year', 'month', 'dayofweek']
users = users.merge(timestamp, how='left')
users = users.rename(columns={"timestamp": "Zindi_Joining_Timestamp"})
users.drop(['dayofweek', 'year', 'month', 'year_month'], axis=1, inplace=True)
users.head()
# Out:
#        User_ID  FeatureX  Country  FeatureY   Points  Zindi_Joining_Timestamp
# 0  ID_N5LTBAPU         0  ID_DMRM         1  group 3                       13
# 1  ID_CLSFQB0S         0   ID_Q02         3  group 3                        2
# 2  ID_RE6T58Y4         0   ID_Q02         0  group 3                       21
# 3  ID_XJQQRJV3         0  ID_Z8BI         0  group 3                       18
# 4  ID_1JHU6A8S         0   ID_Q02         3  group 3                       19

# %%
overall = overall.merge(users, how='left')

sel_cols = ['FeatureX', 'Country', 'FeatureY', 'Points']
overall[sel_cols] = overall[sel_cols].astype(str)

# %% [markdown]
# ## Competitions based features

# %%
usr_comp = pd.read_csv(os.path.join(Config.DATA_DIR,"CompetitionPartipation.csv"), index_col=None)
usr_comp.columns = ['CompID', 'User_ID', 'PublicRank', 'Successful_Sub_Count',
                    'year', 'month', 'dayofweek']
if LOCAL_TEST_RUN:
    test_index = (usr_comp['year']==3)&(usr_comp['month'].isin([10,11,12]))
    usr_comp = usr_comp[~test_index].reset_index(drop=True)

usr_comp_timestamp = usr_comp.merge(timestamp, how='left')
usr_comp_timestamp = usr_comp_timestamp[['User_ID', 'month', 'year', 'timestamp']].drop_duplicates()
usr_comp_timestamp.columns = ['User_ID', 'month', 'year', 'comp_timestamp']
overall = overall.merge(usr_comp_timestamp, how='left')

overall = overall.sort_values(by='timestamp').reset_index(drop=True)

new_column = overall.groupby('User_ID')['comp_timestamp'].apply(lambda x: x.ffill().shift())
overall['comp_timestamp'] = new_column.reset_index(level=0, drop=True)
overall['Months_Since_Last_Comp'] = overall['timestamp'] - overall['comp_timestamp']
overall['Months_Since_Joining_Zindi'] = overall['comp_timestamp'] - overall['Zindi_Joining_Timestamp']

# %% [markdown]
# ## Competitions data

# %%
competitions = pd.read_csv(os.path.join(Config.DATA_DIR,"Competitions.csv"),
                           index_col=None,
                           skipinitialspace=True)
competitions['CompEndTime Year'] = [int(val) if val!='not mapped' else 999 for val in competitions['CompEndTime Year']]
competitions['FeatureC'] = competitions['FeatureC'].fillna(-1).astype(np.int8)
competitions = competitions.merge(
    timestamp,
    left_on=['CompStartTime Year', 'CompStartTime Month'],
    right_on=['year', 'month'],
    how='left')
competitions = competitions.rename(columns={
    'timestamp': 'comp_start_timestamp',
})
competitions.drop(['year', 'month', 'year_month'], axis=1, inplace=True)
competitions = competitions.merge(
    timestamp,
    left_on=['CompEndTime Year', 'CompEndTime Month'],
    right_on=['year', 'month'],
    how='left')
competitions = competitions.rename(columns={
    'timestamp': 'comp_end_timestamp',
})
competitions['comp_end_timestamp'] = competitions['comp_end_timestamp'].fillna(99)
competitions.drop(['year', 'month', 'year_month'], axis=1, inplace=True)
competitions['comp_duration'] = competitions['comp_end_timestamp'] - competitions['comp_start_timestamp']

# %%
import ast
for col in ['FeatureA', 'FeatureB', 'FeatureE']:
    competitions[col] = competitions[col].map(ast.literal_eval)

# %%
# !pip install --upgrade pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.0 MB/s eta 0:00:00
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.4 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 82.3 MB/s eta 0:00:00
# Downloading numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 57.5 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 14.8 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 28.8 MB/s eta 0:00:00
# Installing collected packages: pytz, python-dateutil, numpy, pandas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# accelerate 0.34.2 requires packaging>=20.0, which is not installed.
# albumentations 1.4.15 requires scipy>=1.10.0, which is not installed.
# altair 4.2.2 requires entrypoints, which is not installed.
# altair 4.2.2 requires jinja2, which is not installed.
# altair 4.2.2 requires jsonschema>=3.0, which is not installed.
# arviz 0.19.0 requires matplotlib>=3.5, which is not installed.
# arviz 0.19.0 requires packaging, which is not installed.
# arviz 0.19.0 requires scipy>=1.9.0, which is not installed.
# arviz 0.19.0 requires typing-extensions>=4.1.0, which is not installed.
# astropy 6.1.4 requires packaging>=19.0, which is not installed.
# bigframes 1.22.0 requires ipywidgets>=7.7.1, which is not installed.
# bigframes 1.22.0 requires matplotlib>=3.7.1, which is not installed.
# bigframes 1.22.0 requires requests>=2.27.1, which is not installed.
# bigframes 1.22.0 requires scikit-learn>=1.2.2, which is not installed.
# bigquery-magics 0.4.0 requires ipykernel>=5.5.6, which is not installed.
# bigquery-magics 0.4.0 requires ipython>=7.23.1, which is not installed.
# bigquery-magics 0.4.0 requires ipywidgets>=7.7.1, which is not installed.
# bigquery-magics 0.4.0 requires packaging>=20.0.0, which is not installed.
# bigquery-magics 0.4.0 requires tqdm<5.0.0dev,>=4.7.4, which is not installed.
# bokeh 3.4.3 requires Jinja2>=2.9, which is not installed.
# bokeh 3.4.3 requires packaging>=16.8, which is not installed.
# bokeh 3.4.3 requires pillow>=7.1.0, which is not installed.
# bokeh 3.4.3 requires tornado>=6.2, which is not installed.
# bqplot 0.12.43 requires ipywidgets<9,>=7.5.0, which is not installed.
# bqplot 0.12.43 requires traitlets>=4.3.0, which is not installed.
# chex 0.1.87 requires typing-extensions>=4.2.0, which is not installed.
# clarabel 0.9.0 requires scipy, which is not installed.
# cmdstanpy 1.2.4 requires tqdm, which is not installed.
# cudf-cu12 24.10.1 requires packaging, which is not installed.
# cudf-cu12 24.10.1 requires typing_extensions>=4.0.0, which is not installed.
# cufflinks 0.17.3 requires ipython>=5.3.0, which is not installed.
# cufflinks 0.17.3 requires ipywidgets>=7.0.0, which is not installed.
# cufflinks 0.17.3 requires plotly>=4.1.1, which is not installed.
# cvxpy 1.5.3 requires scipy>=1.1.0, which is not installed.
# datascience 0.17.6 requires ipython, which is not installed.
# datascience 0.17.6 requires matplotlib>=3.0.0, which is not installed.
# datascience 0.17.6 requires plotly, which is not installed.
# datascience 0.17.6 requires scipy, which is not installed.
# db-dtypes 1.3.0 requires packaging>=17.0, which is not installed.
# diffusers 0.30.3 requires Pillow, which is not installed.
# diffusers 0.30.3 requires requests, which is not installed.
# dopamine-rl 4.0.9 requires Pillow>=7.0.0, which is not installed.
# dopamine-rl 4.0.9 requires tqdm>=4.64.1, which is not installed.
# ecos 2.0.14 requires scipy>=0.9, which is not installed.
# fastai 2.7.17 requires matplotlib, which is not installed.
# fastai 2.7.17 requires packaging, which is not installed.
# fastai 2.7.17 requires pillow>=9.0.0, which is not installed.
# fastai 2.7.17 requires requests, which is not installed.
# fastai 2.7.17 requires scikit-learn, which is not installed.
# fastai 2.7.17 requires scipy, which is not installed.
# flax 0.8.5 requires typing-extensions>=4.2, which is not installed.
# folium 0.17.0 requires jinja2>=2.9, which is not installed.
# folium 0.17.0 requires requests, which is not installed.
# geemap 0.34.5 requires matplotlib, which is not installed.
# geemap 0.34.5 requires plotly, which is not installed.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, which is not installed.
# geopandas 1.0.1 requires packaging, which is not installed.
# google-cloud-bigquery 3.25.0 requires packaging>=20.0.0, which is not installed.
# google-cloud-bigquery 3.25.0 requires requests<3.0.0dev,>=2.21.0, which is not installed.
# google-colab 1.0.0 requires ipykernel==5.5.6, which is not installed.
# google-colab 1.0.0 requires ipython==7.34.0, which is not installed.
# google-colab 1.0.0 requires notebook==6.5.5, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, which is not installed.
# google-colab 1.0.0 requires tornado==6.3.3, which is not installed.
# holoviews 1.19.1 requires packaging, which is not installed.
# hyperopt 0.2.7 requires scipy, which is not installed.
# hyperopt 0.2.7 requires tqdm, which is not installed.
# ibis-framework 9.2.0 requires typing-extensions<5,>=4.3.0, which is not installed.
# imageio 2.35.1 requires pillow>=8.3.2, which is not installed.
# imbalanced-learn 0.12.4 requires joblib>=1.1.1, which is not installed.
# imbalanced-learn 0.12.4 requires scikit-learn>=1.0.2, which is not installed.
# imbalanced-learn 0.12.4 requires scipy>=1.5.0, which is not installed.
# imbalanced-learn 0.12.4 requires threadpoolctl>=2.0.0, which is not installed.
# imgaug 0.4.0 requires matplotlib, which is not installed.
# imgaug 0.4.0 requires Pillow, which is not installed.
# imgaug 0.4.0 requires scipy, which is not installed.
# ipyparallel 8.8.0 requires decorator, which is not installed.
# ipyparallel 8.8.0 requires entrypoints, which is not installed.
# ipyparallel 8.8.0 requires ipykernel>=4.4, which is not installed.
# ipyparallel 8.8.0 requires ipython>=4, which is not installed.
# ipyparallel 8.8.0 requires jupyter-client>=5, which is not installed.
# ipyparallel 8.8.0 requires pyzmq>=18, which is not installed.
# ipyparallel 8.8.0 requires tornado>=5.1, which is not installed.
# ipyparallel 8.8.0 requires tqdm, which is not installed.
# ipyparallel 8.8.0 requires traitlets>=4.3, which is not installed.
# jax 0.4.33 requires scipy>=1.10, which is not installed.
# jaxlib 0.4.33 requires scipy>=1.10, which is not installed.
# kaggle 1.6.17 requires bleach, which is not installed.
# kaggle 1.6.17 requires certifi>=2023.7.22, which is not installed.
# kaggle 1.6.17 requires requests, which is not installed.
# kaggle 1.6.17 requires tqdm, which is not installed.
# kaggle 1.6.17 requires urllib3, which is not installed.
# keras 3.4.1 requires packaging, which is not installed.
# librosa 0.10.2.post1 requires decorator>=4.3.0, which is not installed.
# librosa 0.10.2.post1 requires joblib>=0.14, which is not installed.
# librosa 0.10.2.post1 requires scikit-learn>=0.20.0, which is not installed.
# librosa 0.10.2.post1 requires scipy>=1.2.0, which is not installed.
# librosa 0.10.2.post1 requires typing-extensions>=4.1.1, which is not installed.
# matplotlib-venn 1.1.1 requires matplotlib, which is not installed.
# matplotlib-venn 1.1.1 requires scipy, which is not installed.
# missingno 0.5.2 requires matplotlib, which is not installed.
# missingno 0.5.2 requires scipy, which is not installed.
# mizani 0.11.4 requires scipy>=1.7.0, which is not installed.
# mlxtend 0.23.1 requires joblib>=0.13.2, which is not installed.
# mlxtend 0.23.1 requires matplotlib>=3.0.0, which is not installed.
# mlxtend 0.23.1 requires scikit-learn>=1.0.2, which is not installed.
# mlxtend 0.23.1 requires scipy>=1.2.1, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, which is not installed.
# moviepy 1.0.3 requires requests<3.0,>=2.8.1, which is not installed.
# moviepy 1.0.3 requires tqdm<5.0,>=4.11.2, which is not installed.
# music21 9.1.0 requires joblib, which is not installed.
# music21 9.1.0 requires matplotlib, which is not installed.
# music21 9.1.0 requires requests, which is not installed.
# nibabel 5.2.1 requires packaging>=17, which is not installed.
# orbax-checkpoint 0.6.4 requires nest_asyncio, which is not installed.
# orbax-checkpoint 0.6.4 requires typing_extensions, which is not installed.
# osqp 0.6.7.post3 requires scipy>=0.13.2, which is not installed.
# pandas-datareader 0.10.0 requires requests>=2.19.0, which is not installed.
# pandas-gbq 0.23.2 requires packaging>=22.0.0, which is not installed.
# panel 1.4.5 requires bleach, which is not installed.
# panel 1.4.5 requires requests, which is not installed.
# panel 1.4.5 requires tqdm>=4.48.0, which is not installed.
# panel 1.4.5 requires typing-extensions, which is not installed.
# plotnine 0.13.6 requires matplotlib>=3.7.0, which is not installed.
# plotnine 0.13.6 requires scipy>=1.7.0, which is not installed.
# plotnine 0.13.6 requires statsmodels>=0.14.0, which is not installed.
# prophet 1.1.6 requires importlib-resources, which is not installed.
# prophet 1.1.6 requires matplotlib>=2.0.0, which is not installed.
# prophet 1.1.6 requires tqdm>=4.36.1, which is not installed.
# pycocotools 2.0.8 requires matplotlib>=2.1.0, which is not installed.
# pylibcudf-cu12 24.10.1 requires packaging, which is not installed.
# pylibcudf-cu12 24.10.1 requires typing_extensions>=4.0.0, which is not installed.
# pymc 5.16.2 requires scipy>=1.4.1, which is not installed.
# pymc 5.16.2 requires threadpoolctl<4.0.0,>=3.1.0, which is not installed.
# pymc 5.16.2 requires typing-extensions>=3.7.4, which is not installed.
# pyogrio 0.10.0 requires certifi, which is not installed.
# pyogrio 0.10.0 requires packaging, which is not installed.
# pytensor 2.25.5 requires scipy<2,>=1, which is not installed.
# qdldl 0.1.7.post4 requires scipy>=0.13.2, which is not installed.
# rpy2 3.4.2 requires cffi>=1.10.0, which is not installed.
# rpy2 3.4.2 requires jinja2, which is not installed.
# scikit-image 0.24.0 requires packaging>=21, which is not installed.
# scikit-image 0.24.0 requires pillow>=9.1, which is not installed.
# scikit-image 0.24.0 requires scipy>=1.9, which is not installed.
# scs 3.2.7 requires scipy, which is not installed.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.
# shap 0.46.0 requires packaging>20.9, which is not installed.
# shap 0.46.0 requires scikit-learn, which is not installed.
# shap 0.46.0 requires scipy, which is not installed.
# shap 0.46.0 requires tqdm>=4.27.0, which is not installed.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, which is not installed.
# sklearn-pandas 2.2.0 requires scipy>=1.5.1, which is not installed.
# spacy 3.7.5 requires jinja2, which is not installed.
# spacy 3.7.5 requires packaging>=20.0, which is not installed.
# spacy 3.7.5 requires requests<3.0.0,>=2.13.0, which is not installed.
# spacy 3.7.5 requires tqdm<5.0.0,>=4.38.0, which is not installed.
# tables 3.8.0 requires packaging, which is not installed.
# tensorflow 2.17.0 requires packaging, which is not installed.
# tensorflow 2.17.0 requires requests<3,>=2.21.0, which is not installed.
# tensorflow 2.17.0 requires typing-extensions>=3.6.6, which is not installed.
# tensorflow-datasets 4.9.6 requires requests>=2.19.0, which is not installed.
# tensorflow-datasets 4.9.6 requires tqdm, which is not installed.
# tensorflow-probability 0.24.0 requires decorator, which is not installed.
# thinc 8.2.5 requires packaging>=20.0, which is not installed.
# torchvision 0.19.1+cu121 requires pillow!=8.3.*,>=5.3.0, which is not installed.
# transformers 4.44.2 requires packaging>=20.0, which is not installed.
# transformers 4.44.2 requires requests, which is not installed.
# transformers 4.44.2 requires tqdm>=4.27, which is not installed.
# wordcloud 1.9.3 requires matplotlib, which is not installed.
# wordcloud 1.9.3 requires pillow, which is not installed.
# xarray 2024.9.0 requires packaging>=23.1, which is not installed.
# xarray-einstats 0.8.0 requires scipy>=1.9, which is not installed.
# xgboost 2.1.1 requires scipy, which is not installed.
# yellowbrick 1.5 requires cycler>=0.10.0, which is not installed.
# yellowbrick 1.5 requires matplotlib!=3.0.0,>=2.0.2, which is not installed.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, which is not installed.
# yellowbrick 1.5 requires scipy>=1.0.0, which is not installed.
# yfinance 0.2.44 requires requests>=2.31, which is not installed.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.1.2 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.2 which is incompatible.
# pytensor 2.25.5 requires numpy<2,>=1.17.0, but you have numpy 2.1.2 which is incompatible.
# tensorflow 2.17.0 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.1.2 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.2 which is incompatible.
# Successfully installed numpy-2.1.2 pandas-2.2.3 python-dateutil-2.9.0.post0 pytz-2024.2

# %%
comp_features = competitions[['CompID']].copy()
for col in ['FeatureA', 'FeatureB', 'FeatureC', 'FeatureD', 'FeatureE']:
    tmp = competitions[['CompID', col]].explode(column=[col])
    tmp[col] = tmp[col].fillna('empty')
    tmp['count'] = 1

    tmp = tmp.pivot_table(index='CompID',
                    columns=col,
                    values='count',
                    aggfunc='count')
    tmp.columns = [tmp.columns.name + "_" + str(col) for col in tmp.columns]
    tmp = tmp.reset_index()
    comp_features = comp_features.merge(tmp, how='left')
comp_features = comp_features.fillna(0)
comp_features = comp_features.merge(competitions[['CompID', 'comp_start_timestamp']])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-5e555d11b70b> in <cell line: 2>()
#       5     tmp['count'] = 1
#       6
# ----> 7     tmp = tmp.pivot_table(index='CompID',
#       8                     columns=col,
#       9                     values='count',
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in unstack(self, level, fill_value, sort)
#
# ModuleNotFoundError: No module named 'pandas.core.reshape.reshape'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Time based competitions features

# %%
timestamp_ids = []
competitions_ids = []
for t in tqdm(timestamp.timestamp):
    selected_comp = competitions.CompID[(t>=competitions.comp_start_timestamp)&(t<=competitions.comp_end_timestamp)]
    timestamp_ids.extend([t]*len(selected_comp))
    competitions_ids.extend(selected_comp)

timestamp_comp = pd.DataFrame({
    "timestamp": timestamp_ids,
    "CompID": competitions_ids
})
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 2398.73it/s]

# %% [markdown]
# ## Current active competitions feature

# %%
active_comp = usr_comp.merge(timestamp, how='left')
active_comp = active_comp.rename(columns={"timestamp": "comp_timestamp"})
active_comp = active_comp[['User_ID', 'CompID', 'comp_timestamp']].merge(competitions[['CompID', 'comp_start_timestamp', 'comp_end_timestamp']], how='left')
active_comp = active_comp[active_comp['comp_end_timestamp']!=99].reset_index(drop=True)
active_comp = all_timestamps.merge(active_comp, how='left')

active_comp['Current_Active_Competitions'] = (
    (active_comp['timestamp'] > active_comp['comp_timestamp']) &
    (active_comp['timestamp'] <= active_comp['comp_end_timestamp'])
).astype(np.int8)

active_comp = active_comp.groupby(['User_ID', 'timestamp'])['Current_Active_Competitions'].sum()
active_comp = active_comp.reset_index()

overall = overall.merge(active_comp, how='left')

# %% [markdown]
# ## User Interests Feature

# %%
timestamp_comp = timestamp_comp.merge(comp_features, how='left')
timestamp_comp.drop(['comp_start_timestamp', 'CompID'], axis=1, inplace=True)
timestamp_comp = timestamp_comp.groupby('timestamp').agg(np.sum).reset_index()
timestamp_comp = timestamp_comp.sort_values('timestamp').reset_index(drop=True)

usr_comp_timestamp = usr_comp.merge(timestamp, how='left')
usr_comp_features = usr_comp_timestamp[['User_ID', 'CompID', 'timestamp']].merge(comp_features, how='left')
usr_comp_features = usr_comp_features.drop(['CompID', 'comp_start_timestamp'], axis=1)
usr_comp_features = usr_comp_features.groupby(['User_ID', 'timestamp']).agg(np.sum)#.groupby(level=0).cumsum()
usr_comp_features = usr_comp_features.reset_index()
usr_comp_features = all_timestamps.merge(usr_comp_features, how='left')
sel_cols = usr_comp_features.columns[4:]
print(sel_cols)

usr_comp_features = usr_comp_features.sort_values(by='timestamp').reset_index(drop=True)
for col in tqdm(sel_cols):
    usr_comp_features[col] = usr_comp_features.groupby('User_ID')[col].apply(lambda x: x.ffill())

usr_comp_features = usr_comp_features.fillna(0)
# Out:
# Index(['FeatureA_1', 'FeatureA_2', 'FeatureA_3', 'FeatureA_4', 'FeatureA_5',
#        'FeatureA_6', 'FeatureA_7', 'FeatureA_8', 'FeatureA_9', 'FeatureA_10',
#        'FeatureA_empty', 'FeatureB_5', 'FeatureB_6', 'FeatureB_7',
#        'FeatureB_8', 'FeatureB_9', 'FeatureB_10', 'FeatureB_12', 'FeatureB_14',
#        'FeatureB_15', 'FeatureB_16', 'FeatureB_empty', 'FeatureC_-1',
#        'FeatureC_1', 'FeatureC_2', 'FeatureC_3', 'FeatureC_4', 'FeatureC_5',
#        'FeatureC_6', 'FeatureC_7', 'FeatureC_8', 'FeatureC_9', 'FeatureC_10',
#        'FeatureC_11', 'FeatureC_12', 'FeatureC_13', 'FeatureC_14',
#        'FeatureC_15', 'FeatureC_16', 'FeatureC_17', 'FeatureC_18',
#        'FeatureC_19', 'FeatureC_20', 'FeatureC_21', 'FeatureC_22',
#        'FeatureC_23', 'FeatureC_24', 'FeatureC_25', 'FeatureC_26',
#        'FeatureC_27', 'FeatureC_28', 'FeatureC_29', 'FeatureC_30',
#        'FeatureC_31', 'FeatureC_32', 'FeatureC_33', 'FeatureC_34',
#        'FeatureC_35', 'FeatureC_36', 'FeatureC_37', 'FeatureD_1', 'FeatureD_2',
#        'FeatureD_3', 'FeatureE_1', 'FeatureE_2', 'FeatureE_3', 'FeatureE_4',
#        'FeatureE_5', 'FeatureE_6', 'FeatureE_7', 'FeatureE_8', 'FeatureE_9',
#        'FeatureE_10', 'FeatureE_empty'],
#       dtype='object')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [03:14<00:00,  2.63s/it]

# %%
from sklearn.metrics.pairwise import cosine_similarity

timestamp_ids = []
usr_ids = []
user_interests = []

for t in timestamp_comp['timestamp']:
    if t == 1:
        continue
    usr_f = usr_comp_features[usr_comp_features['timestamp']==t-1]
    timestamp_ids.extend([t]*len(usr_f))
    usr_ids.extend(usr_f.pop('User_ID'))

    comp_f = timestamp_comp[timestamp_comp['timestamp']==t]
    usr_f.drop(['timestamp', 'year', 'month'], axis=1, inplace=True)
    comp_f.drop('timestamp', axis=1, inplace=True)

    interests = np.matmul(usr_f.values, comp_f.values.T).flatten()
#     interests = cosine_similarity(usr_f.values, comp_f.values).flatten()
    user_interests.extend(interests)

usr_interest_f = pd.DataFrame({
    "timestamp": timestamp_ids,
    "User_ID": usr_ids,
    "user_interests": user_interests
})

overall = overall.merge(usr_interest_f, how='left')
overall = overall.sort_values(by='timestamp').reset_index(drop=True)
overall['user_interests'] = overall.groupby('User_ID')['user_interests'].apply(lambda x: x.ffill())
overall['user_interests'] = overall['user_interests'].fillna(0)

# %%
comp_hist = usr_comp.groupby(['User_ID', 'year', 'month'])['CompID'].nunique()
comp_hist = comp_hist.reset_index()
comp_hist.columns = [*comp_hist.columns[:-1]] + ['Num_Comp_Prev_Month']

overall = overall.merge(comp_hist, how='left')
overall = overall.sort_values(by=['User_ID', 'timestamp']).reset_index(drop=True)
overall['Num_Comp_Prev_Month'] = overall['Num_Comp_Prev_Month'].fillna(0)
overall['Num_Comp_Per_Month'] = overall.groupby('User_ID')['Num_Comp_Prev_Month'].cumsum()
overall['Num_Comp_Per_Month_trend'] = overall['Num_Comp_Per_Month']/overall['Total_Num_User_Months']
overall['Num_Comp_Per_Month_trend'] = overall.groupby('User_ID')['Num_Comp_Per_Month_trend'].apply(lambda x: x.shift())
overall['Num_Comp_Per_Month'] = overall['Num_Comp_Per_Month']/(overall['timestamp'].max() - overall['Zindi_Joining_Timestamp'])
overall['Num_Comp_Per_Month'] = overall.groupby('User_ID')['Num_Comp_Per_Month'].apply(lambda x: x.shift())

overall['Num_Comp_Prev_Month'] = overall.groupby('User_ID')['Num_Comp_Prev_Month'].apply(lambda x: x.shift())
overall['Num_Comp_Prev_Month_momentum'] = overall['Num_Comp_Prev_Month'] - overall.groupby('User_ID')['Num_Comp_Prev_Month'].apply(lambda x: x.shift(1))
overall['Num_Comp_Prev_Month_momentum2'] = overall['Num_Comp_Prev_Month'] - overall.groupby('User_ID')['Num_Comp_Prev_Month'].apply(lambda x: x.shift(2))

# %%
tmp = usr_comp.groupby(['User_ID', 'year', 'month', 'PublicRank'])['CompID'].nunique().unstack('PublicRank').apply(lambda x: x/x.sum(), axis=1)
col_names = [tmp.columns.name + "_" + str(col) for col in tmp.columns]
tmp.columns = col_names
tmp = tmp.fillna(0)
tmp = tmp.reset_index()

tmp = all_timestamps.merge(tmp, how='left')
tmp = tmp.sort_values(by='timestamp').reset_index(drop=True)
for col in col_names:
    tmp[col] = tmp.groupby('User_ID')[col].apply(lambda x: x.cumsum().ffill().shift())

overall = overall.merge(tmp, how='left')

# %%
tmp = usr_comp.groupby(['User_ID', 'year', 'month', 'Successful_Sub_Count'])['CompID'].nunique().unstack('Successful_Sub_Count').apply(lambda x: x/x.sum(), axis=1)
col_names = [tmp.columns.name + "_" + str(col) for col in tmp.columns]
tmp.columns = col_names
tmp = tmp.fillna(0)
tmp = tmp.reset_index()

tmp = all_timestamps.merge(tmp, how='left')
tmp = tmp.sort_values(by='timestamp').reset_index(drop=True)
for col in col_names:
    tmp[col] = tmp.groupby('User_ID')[col].apply(lambda x: x.cumsum().ffill().shift())

overall = overall.merge(tmp, how='left')

# %%
del usr_comp, usr_comp_timestamp, comp_hist
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Submissions based features

# %%
usr_sub = pd.read_csv(os.path.join(Config.DATA_DIR,"Submissions.csv"), index_col=None)
usr_sub.columns = ['User_ID', 'FeatureG', 'CompID', 'year', 'month', 'dayofweek']

if LOCAL_TEST_RUN:
    test_index = (usr_sub['year']==3)&(usr_sub['month'].isin([10,11,12]))
    usr_sub = usr_sub[~test_index].reset_index(drop=True)

usr_sub_timestamp = usr_sub.merge(timestamp, how='left')
usr_sub_timestamp = usr_sub_timestamp[['User_ID', 'month', 'year', 'timestamp']].drop_duplicates()
usr_sub_timestamp.columns = ['User_ID', 'month', 'year', 'sub_timestamp']
overall = overall.merge(usr_sub_timestamp, how='left')

overall = overall.sort_values(by='timestamp').reset_index(drop=True)
overall['sub_timestamp'] = overall.groupby('User_ID')['sub_timestamp'].apply(lambda x: x.ffill().shift())
overall['Months_Since_Last_Sub'] = overall['timestamp'] - overall['sub_timestamp']
overall['Months_Since_Sub_Joining_Zindi'] = overall['sub_timestamp'] - overall['Zindi_Joining_Timestamp']

# %%
sub_hist = usr_sub.groupby(['User_ID', 'year', 'month']).agg({'CompID': ['nunique', 'count']})
sub_hist.columns = ["_".join(col) for col in sub_hist.columns]
sub_hist['Sub_Per_Comp'] = sub_hist['CompID_nunique']/sub_hist['CompID_count']
sub_hist.drop(['CompID_nunique', 'CompID_count'], axis=1, inplace=True)
sub_hist = sub_hist.reset_index()
sub_hist.columns = [*sub_hist.columns[:-1]] + ['Num_Sub_Prev_Month']

overall = overall.merge(sub_hist, how='left')
overall = overall.sort_values(by=['User_ID', 'timestamp']).reset_index(drop=True)
overall['Num_Sub_Prev_Month'] = overall['Num_Sub_Prev_Month'].fillna(0)
overall['Num_Sub_Per_Month'] = overall.groupby('User_ID')['Num_Sub_Prev_Month'].cumsum()
overall['Num_Sub_Per_Month_trend'] = overall['Num_Sub_Per_Month']/overall['Total_Num_User_Months']
overall['Num_Sub_Per_Month_trend'] = overall.groupby('User_ID')['Num_Sub_Per_Month_trend'].apply(lambda x: x.shift())
overall['Num_Sub_Per_Month'] = overall['Num_Sub_Per_Month']/(overall['timestamp'].max() - overall['Zindi_Joining_Timestamp'])
overall['Num_Sub_Per_Month'] = overall.groupby('User_ID')['Num_Sub_Per_Month'].apply(lambda x: x.shift())

overall['Num_Sub_Prev_Month'] = overall.groupby('User_ID')['Num_Sub_Prev_Month'].apply(lambda x: x.shift())
overall['Num_Sub_Prev_Month_momentum'] = overall['Num_Sub_Prev_Month'] - overall.groupby('User_ID')['Num_Sub_Prev_Month'].apply(lambda x: x.shift(1))
overall['Num_Sub_Prev_Month_momentum2'] = overall['Num_Sub_Prev_Month'] - overall.groupby('User_ID')['Num_Sub_Prev_Month'].apply(lambda x: x.shift(2))

# %%
tmp = usr_sub.groupby(['User_ID', 'year', 'month', 'FeatureG'])['CompID'].nunique().unstack('FeatureG')#.apply(lambda x: x/x.sum(), axis=1)
col_names = [tmp.columns.name + "_" + str(col) for col in tmp.columns]
tmp.columns = col_names
tmp = tmp.fillna(0)
tmp = tmp.reset_index()

all_timestamps = overall[['User_ID', 'timestamp', 'year', 'month']].drop_duplicates().reset_index(drop=True)
tmp = all_timestamps.merge(tmp, how='left')
tmp = tmp.sort_values(by='timestamp').reset_index(drop=True)
for col in col_names:
    tmp[col] = tmp.groupby('User_ID')[col].apply(lambda x: x.ffill().shift())

overall = overall.merge(tmp, how='left')

# %%
del usr_sub, usr_sub_timestamp, sub_hist
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Discussion based features

# %%
usr_dis = pd.read_csv(os.path.join(Config.DATA_DIR,"Discussions.csv"), index_col=None)
usr_dis.columns = ['FeatureF', 'year', 'month', 'dayofweek', 'DiscID', 'User_ID']

if LOCAL_TEST_RUN:
    test_index = (usr_dis['year']==3)&(usr_dis['month'].isin([10,11,12]))
    usr_dis = usr_dis[~test_index].reset_index(drop=True)

usr_dis_timestamp = usr_dis.merge(timestamp, how='left')
usr_dis_timestamp = usr_dis_timestamp[['User_ID', 'month', 'year', 'timestamp']].drop_duplicates()
usr_dis_timestamp.columns = ['User_ID', 'month', 'year', 'discussion_timestamp']
overall = overall.merge(usr_dis_timestamp, how='left')

overall = overall.sort_values(by='timestamp').reset_index(drop=True)
overall['discussion_timestamp'] = overall.groupby('User_ID')['discussion_timestamp'].apply(lambda x: x.ffill().shift())
overall['Months_Since_Last_Dis'] = overall['timestamp'] - overall['discussion_timestamp']
overall['Months_Since_Dis_Joining_Zindi'] = overall['discussion_timestamp'] - overall['Zindi_Joining_Timestamp']

# %%
dis_hist = usr_dis.groupby(['User_ID', 'year', 'month'])['DiscID'].nunique()
dis_hist = dis_hist.reset_index()
dis_hist.columns = [*dis_hist.columns[:-1]] + ['Num_Dis_Prev_Month']

overall = overall.merge(dis_hist, how='left')
overall = overall.sort_values(by=['User_ID', 'timestamp']).reset_index(drop=True)
overall['Num_Dis_Prev_Month'] = overall['Num_Dis_Prev_Month'].fillna(0)
overall['Num_Dis_Per_Month'] = overall.groupby('User_ID')['Num_Dis_Prev_Month'].cumsum()
overall['Num_Dis_Per_Month_trend'] = overall['Num_Dis_Per_Month']/overall['Total_Num_User_Months']
overall['Num_Dis_Per_Month_trend'] = overall.groupby('User_ID')['Num_Dis_Per_Month_trend'].apply(lambda x: x.shift())
overall['Num_Dis_Per_Month'] = overall['Num_Dis_Per_Month']/(overall['timestamp'].max() - overall['Zindi_Joining_Timestamp'])
overall['Num_Dis_Per_Month'] = overall.groupby('User_ID')['Num_Dis_Per_Month'].apply(lambda x: x.shift())

overall['Num_Dis_Prev_Month'] = overall.groupby('User_ID')['Num_Dis_Prev_Month'].apply(lambda x: x.shift())
overall['Num_Dis_Prev_Month_momentum'] = overall['Num_Dis_Prev_Month'] - overall.groupby('User_ID')['Num_Dis_Prev_Month'].apply(lambda x: x.shift(1))
overall['Num_Dis_Prev_Month_momentum2'] = overall['Num_Dis_Prev_Month'] - overall.groupby('User_ID')['Num_Dis_Prev_Month'].apply(lambda x: x.shift(2))

# %%
del usr_dis, usr_dis_timestamp, dis_hist
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Comments based features

# %%
usr_comments = pd.read_csv(os.path.join(Config.DATA_DIR,"Comments.csv"), index_col=None)
usr_comments.columns = ['User_ID', 'year', 'month', 'dayofweek']
usr_comments['CommID'] = np.arange(len(usr_comments))

if LOCAL_TEST_RUN:
    test_index = (usr_comments['year']==3)&(usr_comments['month'].isin([10,11,12]))
    usr_comments = usr_comments[~test_index].reset_index(drop=True)

usr_comm_timestamp = usr_comments.merge(timestamp, how='left')
usr_comm_timestamp = usr_comm_timestamp[['User_ID', 'month', 'year', 'timestamp']].drop_duplicates()
usr_comm_timestamp.columns = ['User_ID', 'month', 'year', 'comment_timestamp']
overall = overall.merge(usr_comm_timestamp, how='left')

overall = overall.sort_values(by='timestamp').reset_index(drop=True)
overall['comment_timestamp'] = overall.groupby('User_ID')['comment_timestamp'].apply(lambda x: x.ffill().shift())
overall['Months_Since_Last_Comment'] = overall['timestamp'] - overall['comment_timestamp']
overall['Months_Since_Comment_Joining_Zindi'] = overall['comment_timestamp'] - overall['Zindi_Joining_Timestamp']

# %%
comm_hist = usr_comments.groupby(['User_ID', 'year', 'month'])['CommID'].nunique()
comm_hist = comm_hist.reset_index()
comm_hist.columns = [*comm_hist.columns[:-1]] + ['Num_Comm_Prev_Month']

overall = overall.merge(comm_hist, how='left')
overall = overall.sort_values(by=['User_ID', 'timestamp']).reset_index(drop=True)
overall['Num_Comm_Prev_Month'] = overall['Num_Comm_Prev_Month'].fillna(0)
overall['Num_Comm_Per_Month'] = overall.groupby('User_ID')['Num_Comm_Prev_Month'].cumsum()
overall['Num_Comm_Per_Month_trend'] = overall['Num_Comm_Per_Month']/overall['Total_Num_User_Months']
overall['Num_Comm_Per_Month_trend'] = overall.groupby('User_ID')['Num_Comm_Per_Month_trend'].apply(lambda x: x.shift())
overall['Num_Comm_Per_Month'] = overall['Num_Comm_Per_Month']/(overall['timestamp'].max() - overall['Zindi_Joining_Timestamp'])
overall['Num_Comm_Per_Month'] = overall.groupby('User_ID')['Num_Comm_Per_Month'].apply(lambda x: x.shift())

overall['Num_Comm_Prev_Month'] = overall.groupby('User_ID')['Num_Comm_Prev_Month'].apply(lambda x: x.shift())
overall['Num_Comm_Prev_Month_momentum'] = overall['Num_Comm_Prev_Month'] - overall.groupby('User_ID')['Num_Comm_Prev_Month'].apply(lambda x: x.shift(1))
overall['Num_Comm_Prev_Month_momentum2'] = overall['Num_Comm_Prev_Month'] - overall.groupby('User_ID')['Num_Comm_Prev_Month'].apply(lambda x: x.shift(2))

# %%
del usr_comments, usr_comm_timestamp, comm_hist
gc.collect()
# Out:
# 0

# %%
tmp = overall.groupby('timestamp').agg({
    "User_ID": ["nunique"],
    "Total_Num_User_Months": ["mean", "max", "std"],
})
tmp.columns = ["_".join(col) for col in tmp.columns]
tmp = tmp.reset_index()

overall = overall.merge(tmp, how='left')

# %%
sel_cols = ['Months_Since_Last_Comp', 'Months_Since_Last_Dis', 'Months_Since_Last_Sub', 'Months_Since_Last_Comment']
overall['Months_Since_Last_Activity_Mean'] = overall[sel_cols].std(axis=1)

# %%
time_cols = [
    'Zindi_Joining_Timestamp',
    'comment_timestamp',
    'comp_timestamp',
    'discussion_timestamp',
    'sub_timestamp',
    'Months_Since_Last_Comp',
    'Months_Since_Last_Sub',
    'Months_Since_Last_Dis',
    'Months_Since_Last_Comment',
]

for col in time_cols:
    overall[col] = overall[col]/overall['timestamp']

# %%
tmp_time = overall[overall['Zindi_Joining_Timestamp']==1]
tmp_time = tmp_time.groupby('timestamp')['User_ID'].nunique().to_frame("unique_user_count")
tmp_time = tmp_time.reset_index()

overall = overall.merge(tmp_time, how='left')

# %%
overall['user_interests_rank'] = overall.groupby('timestamp')['user_interests'].apply(lambda x:
                                                                                      x.rank(method='dense', ascending=False))

# %%
# overall.loc[overall['user_interests']==0, 'user_interests'] = np.NaN
print(train.shape, test.shape)
train, test = overall[overall['is_train']==1], overall[overall['is_train']==0]
print(train.shape, test.shape)
# Out:
# (259832, 9) (65223, 4)
# (259832, 81) (65223, 81)

# %% [markdown]
# # Modeling

# %%
def train_model(df_trainX, df_trainY, df_evalX, df_evalY, cat_cols, model_name='CAT', params=None):
    from sklearn.metrics import roc_auc_score
    if model_name == 'CAT':
        if params is None:
            params={'n_estimators':10000,'random_state':123,'cat_features':cat_cols}
        clf=CatBoostClassifier(**params,early_stopping_rounds=50,eval_metric='AUC')
        clf.fit(df_trainX,df_trainY,eval_set=(df_evalX,df_evalY),plot=False, verbose=50)
        valid_score = clf.get_best_score().get('validation').get('AUC')
        best_iteration = clf.get_best_iteration()
        feature_score = clf.get_feature_importance()
    elif model_name == 'LGB':
        if params is None:
            params={'verbose':0,'n_estimators':10000,'random_state':123,'learning_rate':0.01,'force_row_wise':True,'colsample_bytree':0.3}
        clf = lgb.LGBMClassifier(**params, importance_type='gain', metric='auc_mu', num_leaves=127, min_child_samples=5)
        callbacks = [lgb.early_stopping(500, verbose=0)]
        clf.fit(df_trainX,
                df_trainY,#)
                eval_set=[(df_evalX, df_evalY)],
                callbacks=callbacks,
                verbose=0
               )

        valid_score = roc_auc_score(df_evalY!='NoActivity', 1-clf.predict_proba(df_evalX)[:,1])
        best_iteration = clf.booster_.best_iteration
        feature_score = clf.feature_importances_
    return clf, valid_score, best_iteration, feature_score

# %%
train.to_csv(os.path.join(Config.DATA_DIR,"Train_fe.csv.gz"), compression='gzip')
test.to_csv(os.path.join(Config.DATA_DIR,"Test_fe.csv.gz"), compression='gzip')

# %%
# %%time

drop_cols = [
    'year', 'month', 'Target', 'Sub', 'CompPart', 'Comment', 'Disc',
    'is_train', 'timestamp', 'Record', 'Active_Month', 'Total_Num_User_Months',
    'user_interests'
]
cat_cols = list(
    set(train.columns[train.dtypes == 'object']) - set(drop_cols) - set(['User_ID'])
)
num_cols = list(set(train.columns) - set(cat_cols + drop_cols))

train_X = train[cat_cols + num_cols]
train_X[cat_cols] = train_X[cat_cols].astype('category')
train_Y = train['Target']

test_X = test[cat_cols + num_cols]
test_X[cat_cols] = test_X[cat_cols].astype('category')

fold = GroupKFold(n_splits=5)
cb_scores, pred_cb, feat_scores = [], [], []
for it, (idxT, idxV) in enumerate(
        fold.split(train_X, train_Y, groups=train['timestamp'])):
    df_trainX, df_trainY = train_X.iloc[idxT], train_Y.iloc[idxT]
    df_evalX, df_evalY = train_X.iloc[idxV], train_Y.iloc[idxV]
    df_testX = test_X.copy()

    selected_cat_cols = ['Country']
    cat_cols_count = [f'{col}_count' for col in selected_cat_cols]
    df_trainX[cat_cols_count] = df_trainX[selected_cat_cols].copy()
    df_evalX[cat_cols_count] = df_evalX[selected_cat_cols].copy()
    df_testX[cat_cols_count] = df_testX[selected_cat_cols].copy()

    encoder = CountEncoder(cols=cat_cols_count + ['User_ID'])
    df_trainX = encoder.fit_transform(df_trainX, df_trainY)
    df_evalX = encoder.transform(df_evalX)
    df_testX = encoder.transform(df_testX)

    clf, valid_score, best_iteration, feature_score = train_model(
        df_trainX, df_trainY, df_evalX, df_evalY, cat_cols, model_name='LGB')
    cb_scores.append(valid_score)
    pred_cb.append(clf.predict_proba(df_testX)[:, 1])
    feat_scores.append(feature_score)
    print('Fold {} {} at {}'.format(it + 1, valid_score, best_iteration))

weights = cb_scores / sum(np.array(cb_scores))
print('The local CV is {}'.format(np.sum(weights * cb_scores)))
# Out:
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# Fold 1 0.9050635572161991 at 668
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# Fold 2 0.9044670487830438 at 913
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# Fold 3 0.9080523301191019 at 424
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# Fold 4 0.9024576875811107 at 746
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# Fold 5 0.9081277085785924 at 1184
# The local CV is 0.9056389319496082
# CPU times: user 1h 6min 33s, sys: 1min 3s, total: 1h 7min 36s
# Wall time: 6min 6s

# %%
if LOCAL_TEST_RUN:
    weights=cb_scores/sum(np.array(cb_scores))
    print ('The local CV is {}'.format(np.sum(weights*cb_scores)))

    prediction = np.sum(weights*np.transpose(pred_cb),1)
    from sklearn.metrics import roc_auc_score
    print("Test score is {}".format(roc_auc_score(test['Target']!='NoActivity', 1-prediction)))

# %%
featureImp=pd.DataFrame({'feature':df_trainX.columns,'importance':np.mean(np.array(feat_scores),0)})
featureImp=featureImp.sort_values('importance',ascending=False)
featureImp['importance']=featureImp['importance']*100/featureImp['importance'].sum()
featureImp.reset_index(drop=True)
# Out:
#                                feature  importance
# 0                  Num_Comp_Prev_Month    9.037149
# 1                   Num_Sub_Prev_Month    9.007915
# 2             Num_Comp_Per_Month_trend    8.885045
# 3                   Num_Comp_Per_Month    7.023674
# 4                               Points    4.678487
# 5          Current_Active_Competitions    4.198269
# 6              Zindi_Joining_Timestamp    3.375272
# 7                        sub_timestamp    3.290834
# 8                              Country    2.535924
# 9               Months_Since_Last_Comp    2.481734
# 10               Months_Since_Last_Sub    2.284014
# 11                 user_interests_rank    2.080107
# 12                     User_ID_nunique    2.078042
# 13                      comp_timestamp    2.011407
# 14                 Num_Comm_Prev_Month    1.875548
# 15            Num_Comm_Per_Month_trend    1.765395
# 16          Months_Since_Joining_Zindi    1.723902
# 17         Num_Sub_Prev_Month_momentum    1.713266
# 18                             User_ID    1.663058
# 19                       Country_count    1.526995
# 20                  Num_Comm_Per_Month    1.425225
# 21      Months_Since_Sub_Joining_Zindi    1.260742
# 22          Total_Num_User_Months_mean    1.257454
# 23                   Num_Sub_Per_Month    1.222074
# 24        Num_Comp_Prev_Month_momentum    1.181587
# 25                   unique_user_count    1.163326
# 26                  Num_Dis_Prev_Month    1.152274
# 27       Successful_Sub_Count_count 10    1.128178
# 28             Num_Sub_Per_Month_trend    1.104089
# 29           Total_Num_User_Months_std    1.094354
# 30                          FeatureG_1    0.964176
# 31        Num_Sub_Prev_Month_momentum2    0.903752
# 32                          year_month    0.752662
# 33     Months_Since_Last_Activity_Mean    0.740189
# 34                            FeatureX    0.707856
# 35                   Num_Dis_Per_Month    0.645148
# 36       Num_Comp_Prev_Month_momentum2    0.621522
# 37                   comment_timestamp    0.552447
# 38        Successful_Sub_Count_count 6    0.504908
# 39        Num_Comm_Prev_Month_momentum    0.498088
# 40                  PublicRank_rank 11    0.492490
# 41                discussion_timestamp    0.472571
# 42           Total_Num_User_Months_max    0.438610
# 43        Successful_Sub_Count_count 3    0.422899
# 44                          FeatureG_0    0.406344
# 45                            FeatureY    0.371450
# 46           Months_Since_Last_Comment    0.347444
# 47         Num_Dis_Prev_Month_momentum    0.346420
# 48  Months_Since_Comment_Joining_Zindi    0.341968
# 49             Num_Dis_Per_Month_trend    0.322711
# 50               Months_Since_Last_Dis    0.310982
# 51        Successful_Sub_Count_count 8    0.304535
# 52        Successful_Sub_Count_count 7    0.300377
# 53        Successful_Sub_Count_count 9    0.296907
# 54                   PublicRank_rank 1    0.272648
# 55       Num_Comm_Prev_Month_momentum2    0.259996
# 56      Months_Since_Dis_Joining_Zindi    0.258565
# 57        Successful_Sub_Count_count 5    0.202630
# 58                          FeatureG_3    0.199760
# 59                   PublicRank_rank 9    0.195073
# 60                  PublicRank_rank 10    0.190304
# 61        Successful_Sub_Count_count 4    0.179139
# 62                   PublicRank_rank 2    0.160982
# 63        Num_Dis_Prev_Month_momentum2    0.155268
# 64                   PublicRank_rank 5    0.136916
# 65                   PublicRank_rank 8    0.129792
# 66                   PublicRank_rank 7    0.122258
# 67                   PublicRank_rank 3    0.099241
# 68                   PublicRank_rank 6    0.086978
# 69                   PublicRank_rank 4    0.058654

# %% [markdown]
# # Submission

# %%
test['Target'] = np.sum(weights * np.transpose(pred_cb), 1)
test['Target'] = 1 - test['Target']
test['UserMonthYear'] = test['User_ID'] + "_" + test['month'].astype(str) + "_" + test['year'].astype(str)
test[['UserMonthYear', 'Target']].to_csv(os.path.join(Config.OUTPUT_DIR, f'{Config.VER}.csv'), index=False)

# %%
test[['UserMonthYear', 'Target']]
# Out:
#           UserMonthYear    Target
# 13      ID_000VV0KM_1_4  0.014111
# 14      ID_000VV0KM_2_4  0.014824
# 15      ID_000VV0KM_3_4  0.010529
# 16      ID_003OCIYO_1_4  0.328175
# 17      ID_003OCIYO_2_4  0.017162
# ...                 ...       ...
# 325041  ID_ZZVPF22K_2_4  0.161856
# 325042  ID_ZZVPF22K_3_4  0.108418
# 325052  ID_ZZXDLYXB_1_4  0.008774
# 325053  ID_ZZXDLYXB_2_4  0.008380
# 325054  ID_ZZXDLYXB_3_4  0.008036
#
# [65223 rows x 2 columns]
